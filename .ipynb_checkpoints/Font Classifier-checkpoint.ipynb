# %% [markdown]
# # Font Classifier - Created by Noopur Singh
#
# ### Problem Statement :
#
# #### Create a Font Classifier. The classifier should take a single image as input and return the name (or label) of the font used in the image from a predefined list of 10 fonts.
#
#
# ### Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import random
from IPython.display import display, Markdown

# %matplotlib inline

import PIL
from PIL import Image

from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D , UpSampling2D ,Conv2DTranspose
from keras.optimizers import SGD
from keras.optimizers.schedules import ExponentialDecay
from keras import callbacks
from keras.models import load_model
from keras.preprocessing.image import img_to_array

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Checking the data present in the directory

print(os.listdir('data'))
# Out:
# ['AlexBrush', 'I Love Glitter', '.DS_Store', 'Holligate Signature', 'Canterbury', 'AguafinaScript', 'James Fajardo', 'GreatVibes', 'Allura', 'alsscrp', 'OpenSans']

# %%
# Accessing the fonts within the directory

data_path = 'data/'
font_AguafinaScript = os.path.join(data_path+'AguafinaScript')

# %%
# Listing the images present within the font folder

font_AguafinaScript_files = os.listdir(font_AguafinaScript)

# %%
# Checking the head of the data

print(font_AguafinaScript_files[:5])
# Out:
# ['image_15.png', 'image_29.png', 'image_28.png', 'image_14.png', 'image_16.png']

# %%
# Listing all possible font directories in folder

font_AlexBrush = os.path.join(data_path+'AlexBrush')

font_Allura = os.path.join(data_path+'Allura')

font_alsscrp = os.path.join(data_path+'alsscrp')

font_Canterbury = os.path.join(data_path+'Canterbury')

font_GreatVibes = os.path.join(data_path+'GreatVibes')

font_Holligate_Signature = os.path.join(data_path+'Holligate Signature')

font_I_Love_Glitter = os.path.join(data_path+'I Love Glitter')

font_James_Fajardo = os.path.join(data_path+'James Fajardo')

font_OpenSans = os.path.join(data_path+'OpenSans')

# Making list of all directories

dir_list = [font_AguafinaScript,font_AlexBrush,font_Allura,font_alsscrp,font_Canterbury,font_GreatVibes,
            font_Holligate_Signature,font_I_Love_Glitter,font_James_Fajardo,font_OpenSans]

# %% [markdown]
# #### Viewing the images from different fonts

# %%
for dir_name in dir_list:

    image_list = [os.path.join(dir_name,fname) for fname in os.listdir(dir_name)[0:4]]

    total_images = len(os.listdir(dir_name))

    display(Markdown(f"## <b><u>Images from {dir_name.split('/')[-1]}, Total Images: {total_images}</u></b>"))


    fig, axes = plt.subplots(nrows=1, ncols=len(image_list), figsize=(20, 5))

    for i, img_path in enumerate(image_list):

        img = mpimg.imread(img_path)
        if len(image_list) == 1:
            ax = axes
        else:
            ax = axes[i]
        ax.imshow(img)
        ax.axis('off')
    plt.show()
# Out:
# ## <b><u>Images from AguafinaScript, Total Images: 83</u></b>
# ## <b><u>Images from AlexBrush, Total Images: 78</u></b>
# ## <b><u>Images from Allura, Total Images: 70</u></b>
# ## <b><u>Images from alsscrp, Total Images: 102</u></b>
# ## <b><u>Images from Canterbury, Total Images: 76</u></b>
# ## <b><u>Images from GreatVibes, Total Images: 76</u></b>
# ## <b><u>Images from Holligate Signature, Total Images: 82</u></b>
# ## <b><u>Images from I Love Glitter, Total Images: 72</u></b>
# ## <b><u>Images from James Fajardo, Total Images: 80</u></b>
# ## <b><u>Images from OpenSans, Total Images: 73</u></b>

# %% [markdown]
# ### Data Collection
#
# ##### For testing purposes, images are generated using various .ttf font files from the fonts directory. Each font file is used to render specified text strings on images of a fixed size. The generated test images are saved in the output directory with filenames indicating the font and text content.
#
# #### Final Dataset for Training
#
# ###### The final dataset used for training and evaluation is provided in the data folder. This dataset is well-organized, with subdirectories for each font type. Each subdirectory contains images of text rendered in that font. This structure allows for straightforward loading and preprocessing of the data, ensuring consistency and ease of use in model training.
#
# ##### Images: The dataset includes multiple images per font, each labeled according to the font type.
# ##### Labels: The labels are derived from the directory names, making it easy to map each image to its corresponding font class.

# %% [markdown]
# ### Data Preprocessing
#
# #### Loading and Resizing: Images are loaded and resized to a uniform size.

# %%
# Funtion to convert the labels into integers

def convert_label(label):
    if label == 'AguafinaScript':
        return 0
    elif label == 'AlexBrush':
        return 1
    elif label == 'Allura':
        return 2
    elif label == 'alsscrp':
        return 3
    elif label == 'Canterbury':
        return 4
    elif label == 'GreatVibes':
        return 5
    elif label == 'Holligate Signature':
        return 6
    elif label == 'I Love Glitter':
        return 7
    elif label == 'James Fajardo':
        return 8
    elif label == 'OpenSans':
        return 9

# %%
X_data = []

Y_data = []


for dir_name in dir_list:

    font_label = dir_name.split(os.path.sep)[-1]

    num_label = convert_label(font_label)

    for fname in os.listdir(dir_name):

        try:
            img = Image.open(os.path.join(dir_name,fname))

            img=img.resize((105,105))

            img.load()

            img_data = np.asarray(img, dtype=np.int16)
            X_data.append(img_data)
            Y_data.append(num_label)
        except:
            None


            
print(f'Length of X data: {len(X_data)}')
print(f'Length of Y data: {len(Y_data)}')
# Out:
# Length of X data: 792
# Length of Y data: 792

# %% [markdown]
# #### The pixel values of the images are normalized to the range [0, 1] by dividing by 255.0

# %%
# converting the input data to a NumPy array of type float and normalizing the pixel values

X_data = np.asarray(X_data, dtype="float") / 255.0
Y_data = np.array(Y_data)

# %% [markdown]
# #### Splitting the dataset into train and test. The test set is considered to be 25%
#
# #### Performing one-hot encoding on the dependent value

# %%
(trainX, testX, trainY, testY) = train_test_split(X_data,Y_data, test_size=0.25, random_state=42)

# Applying one-hot encoding
trainY = to_categorical(trainY, num_classes=10)
testY = to_categorical(testY, num_classes=10)

# %% [markdown]
# ### Model Building

# %% [markdown]
# #### Got model with very bad accuracy and loss_value by using below conv layers

# %%
# model = Sequential([
#     # This is the first convolution
#     Conv2D(32, (3, 3), activation='relu', input_shape=(105, 105, 3)),
#     BatchNormalization(),
#     MaxPooling2D(2, 2),
#     Dropout(0.25),
    
#     # The second convolution
#     Conv2D(64, (3, 3),  activation='relu'),
#     BatchNormalization(),
#     MaxPooling2D(2, 2),
#     Dropout(0.25),
    
#     # The third convolution
#     Conv2D(128, (3, 3), activation='relu'),
#     BatchNormalization(),
#     MaxPooling2D(2, 2),
#     Dropout(0.25),
    
#     # The fourth convolution
#     Conv2D(256, (3, 3), activation='relu'),
#     BatchNormalization(),
#     MaxPooling2D(2, 2),
#     Dropout(0.25),
    
#     Flatten(),
    
#     Dense(512, activation = 'relu'),
#     Dropout(0.5),
    
#     Dense(10, activation='softmax')
# ])

# %% [markdown]
# #### Rebuilding model using lesser conv layers with higher dimesnions of parameters

# %%
model = Sequential([
    
    # The first convolution
    Conv2D(64, (48,48), activation='relu', input_shape=(105,105,3)),
    MaxPooling2D(2, 2),
    
    # The second convolution
    
    Conv2D(128, (24,24), activation='relu'),
    MaxPooling2D(2,2),
    
    Flatten(),
    Dropout(0.5),
    
    # 512 neuron hidden layer
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_21 (Conv2D)              │ (None, 58, 58, 64)     │       442,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 29, 29, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 6, 6, 128)      │     4,718,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,756,618 (21.96 MB)
#  Trainable params: 5,756,618 (21.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Setting up an SGD optimizer with Nesterov momentum and an exponentially decaying learning rate, and then compiling the model to use this optimizer with mean squared error loss and accuracy as a metric.

# %%
lr_schedule = ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)
sgd = SGD(learning_rate=lr_schedule, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# %% [markdown]
# ### Rationale for Chosen Metrics
#
# #### Accuracy is chosen as the primary metric to directly measure the proportion of correct predictions, which is a straightforward indicator of how well the classifier is performing.
#
# #### Loss (Mean Squared Error) is monitored to ensure that the model is learning effectively and to provide an additional measure of performance during training.
#
# #### By using these metrics, I am evaluating the model's performance comprehensively and ensuring that it meets the objectives of font classification effectively.

# %% [markdown]
# ### Model Training
#
# #### Training the model with early stopping and checkpointing based on validation loss, shuffling the data, splitting 20% for validation, and then evaluating the model on the test data.

# %%
filepath='top_model.keras' # The best model will be saved as this

batch_size = 64
epochs = 100

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True)

checkpoint = callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model.fit(trainX, trainY,shuffle=True,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2,
          verbose=1,
          validation_data=(testX, testY),callbacks=[early_stopping,checkpoint])
score = model.evaluate(testX, testY, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1139 - loss: 0.0900
# Epoch 1: val_loss improved from inf to 0.08987, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.1147 - loss: 0.0900 - val_accuracy: 0.1313 - val_loss: 0.0899
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1261 - loss: 0.0900
# Epoch 2: val_loss improved from 0.08987 to 0.08966, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.1273 - loss: 0.0900 - val_accuracy: 0.1263 - val_loss: 0.0897
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1116 - loss: 0.0896
# Epoch 3: val_loss improved from 0.08966 to 0.08932, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.1128 - loss: 0.0896 - val_accuracy: 0.1313 - val_loss: 0.0893
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1180 - loss: 0.0897
# Epoch 4: val_loss improved from 0.08932 to 0.08882, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.1196 - loss: 0.0897 - val_accuracy: 0.2323 - val_loss: 0.0888
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1718 - loss: 0.0890
# Epoch 5: val_loss improved from 0.08882 to 0.08818, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.1729 - loss: 0.0890 - val_accuracy: 0.2020 - val_loss: 0.0882
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1740 - loss: 0.0887
# Epoch 6: val_loss improved from 0.08818 to 0.08743, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.1766 - loss: 0.0887 - val_accuracy: 0.4091 - val_loss: 0.0874
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2548 - loss: 0.0873
# Epoch 7: val_loss improved from 0.08743 to 0.08572, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.2567 - loss: 0.0873 - val_accuracy: 0.4192 - val_loss: 0.0857
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2661 - loss: 0.0869
# Epoch 8: val_loss improved from 0.08572 to 0.08334, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.2695 - loss: 0.0868 - val_accuracy: 0.4141 - val_loss: 0.0833
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3415 - loss: 0.0835
# Epoch 9: val_loss improved from 0.08334 to 0.07877, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.3411 - loss: 0.0835 - val_accuracy: 0.4242 - val_loss: 0.0788
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3608 - loss: 0.0803
# Epoch 10: val_loss improved from 0.07877 to 0.07271, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.3623 - loss: 0.0802 - val_accuracy: 0.4141 - val_loss: 0.0727
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3924 - loss: 0.0757
# Epoch 11: val_loss improved from 0.07271 to 0.06658, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.3913 - loss: 0.0757 - val_accuracy: 0.4343 - val_loss: 0.0666
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4445 - loss: 0.0695
# Epoch 12: val_loss improved from 0.06658 to 0.06098, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.4456 - loss: 0.0695 - val_accuracy: 0.4747 - val_loss: 0.0610
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4706 - loss: 0.0637
# Epoch 13: val_loss improved from 0.06098 to 0.05828, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.4704 - loss: 0.0637 - val_accuracy: 0.4747 - val_loss: 0.0583
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.5265 - loss: 0.0591
# Epoch 14: val_loss did not improve from 0.05828
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.5272 - loss: 0.0591 - val_accuracy: 0.4747 - val_loss: 0.0605
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.5319 - loss: 0.0596
# Epoch 15: val_loss improved from 0.05828 to 0.05276, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.5328 - loss: 0.0595 - val_accuracy: 0.5707 - val_loss: 0.0528
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.5538 - loss: 0.0554
# Epoch 16: val_loss improved from 0.05276 to 0.05160, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.5539 - loss: 0.0554 - val_accuracy: 0.6111 - val_loss: 0.0516
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.5736 - loss: 0.0545
# Epoch 17: val_loss improved from 0.05160 to 0.05057, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.5745 - loss: 0.0545 - val_accuracy: 0.5909 - val_loss: 0.0506
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.5995 - loss: 0.0515
# Epoch 18: val_loss improved from 0.05057 to 0.04900, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.6007 - loss: 0.0515 - val_accuracy: 0.6970 - val_loss: 0.0490
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6130 - loss: 0.0523
# Epoch 19: val_loss did not improve from 0.04900
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.6165 - loss: 0.0520 - val_accuracy: 0.6162 - val_loss: 0.0510
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6490 - loss: 0.0495
# Epoch 20: val_loss did not improve from 0.04900
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.6483 - loss: 0.0495 - val_accuracy: 0.5859 - val_loss: 0.0527
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6538 - loss: 0.0496
# Epoch 21: val_loss improved from 0.04900 to 0.04452, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.6542 - loss: 0.0494 - val_accuracy: 0.6869 - val_loss: 0.0445
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.6385 - loss: 0.0459
# Epoch 22: val_loss improved from 0.04452 to 0.04265, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 74s 7s/step - accuracy: 0.6397 - loss: 0.0459 - val_accuracy: 0.6566 - val_loss: 0.0426
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6643 - loss: 0.0449
# Epoch 23: val_loss did not improve from 0.04265
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.6659 - loss: 0.0448 - val_accuracy: 0.6515 - val_loss: 0.0440
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6866 - loss: 0.0431
# Epoch 24: val_loss improved from 0.04265 to 0.04213, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.6866 - loss: 0.0430 - val_accuracy: 0.6919 - val_loss: 0.0421
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7001 - loss: 0.0407
# Epoch 25: val_loss improved from 0.04213 to 0.03942, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.7003 - loss: 0.0407 - val_accuracy: 0.7273 - val_loss: 0.0394
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7358 - loss: 0.0374
# Epoch 26: val_loss did not improve from 0.03942
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.7351 - loss: 0.0374 - val_accuracy: 0.6970 - val_loss: 0.0409
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7298 - loss: 0.0375
# Epoch 27: val_loss did not improve from 0.03942
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.7300 - loss: 0.0375 - val_accuracy: 0.7424 - val_loss: 0.0396
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7110 - loss: 0.0390
# Epoch 28: val_loss improved from 0.03942 to 0.03716, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 67s 7s/step - accuracy: 0.7117 - loss: 0.0389 - val_accuracy: 0.7576 - val_loss: 0.0372
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7268 - loss: 0.0378
# Epoch 29: val_loss improved from 0.03716 to 0.03512, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7292 - loss: 0.0375 - val_accuracy: 0.7677 - val_loss: 0.0351
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7661 - loss: 0.0327
# Epoch 30: val_loss did not improve from 0.03512
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 67s 7s/step - accuracy: 0.7653 - loss: 0.0328 - val_accuracy: 0.7222 - val_loss: 0.0378
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7810 - loss: 0.0329
# Epoch 31: val_loss did not improve from 0.03512
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7807 - loss: 0.0329 - val_accuracy: 0.7374 - val_loss: 0.0367
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7509 - loss: 0.0325
# Epoch 32: val_loss did not improve from 0.03512
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7521 - loss: 0.0324 - val_accuracy: 0.7273 - val_loss: 0.0363
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7645 - loss: 0.0315
# Epoch 33: val_loss did not improve from 0.03512
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7641 - loss: 0.0316 - val_accuracy: 0.7626 - val_loss: 0.0353
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7740 - loss: 0.0331
# Epoch 34: val_loss improved from 0.03512 to 0.03421, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7753 - loss: 0.0329 - val_accuracy: 0.7778 - val_loss: 0.0342
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7877 - loss: 0.0292
# Epoch 35: val_loss did not improve from 0.03421
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.7874 - loss: 0.0293 - val_accuracy: 0.7273 - val_loss: 0.0369
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7837 - loss: 0.0309
# Epoch 36: val_loss improved from 0.03421 to 0.03364, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.7852 - loss: 0.0308 - val_accuracy: 0.7374 - val_loss: 0.0336
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7712 - loss: 0.0313
# Epoch 37: val_loss improved from 0.03364 to 0.03290, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7724 - loss: 0.0311 - val_accuracy: 0.7576 - val_loss: 0.0329
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8076 - loss: 0.0270
# Epoch 38: val_loss did not improve from 0.03290
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.8058 - loss: 0.0271 - val_accuracy: 0.7273 - val_loss: 0.0338
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7742 - loss: 0.0295
# Epoch 39: val_loss improved from 0.03290 to 0.03037, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.7756 - loss: 0.0293 - val_accuracy: 0.7677 - val_loss: 0.0304
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8183 - loss: 0.0256
# Epoch 40: val_loss improved from 0.03037 to 0.02905, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.8187 - loss: 0.0257 - val_accuracy: 0.8182 - val_loss: 0.0290
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8301 - loss: 0.0244
# Epoch 41: val_loss did not improve from 0.02905
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 74s 7s/step - accuracy: 0.8296 - loss: 0.0244 - val_accuracy: 0.7525 - val_loss: 0.0320
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8253 - loss: 0.0250
# Epoch 42: val_loss improved from 0.02905 to 0.02740, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 67s 7s/step - accuracy: 0.8252 - loss: 0.0251 - val_accuracy: 0.8131 - val_loss: 0.0274
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8101 - loss: 0.0266
# Epoch 43: val_loss did not improve from 0.02740
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 73s 7s/step - accuracy: 0.8115 - loss: 0.0265 - val_accuracy: 0.7677 - val_loss: 0.0319
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8046 - loss: 0.0253
# Epoch 44: val_loss did not improve from 0.02740
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 67s 7s/step - accuracy: 0.8053 - loss: 0.0253 - val_accuracy: 0.7727 - val_loss: 0.0312
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8270 - loss: 0.0247
# Epoch 45: val_loss did not improve from 0.02740
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.8279 - loss: 0.0247 - val_accuracy: 0.8131 - val_loss: 0.0283
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8455 - loss: 0.0228
# Epoch 46: val_loss did not improve from 0.02740
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 72s 7s/step - accuracy: 0.8446 - loss: 0.0229 - val_accuracy: 0.7879 - val_loss: 0.0305
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8532 - loss: 0.0224
# Epoch 47: val_loss improved from 0.02740 to 0.02620, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 72s 7s/step - accuracy: 0.8531 - loss: 0.0224 - val_accuracy: 0.8333 - val_loss: 0.0262
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8576 - loss: 0.0219
# Epoch 48: val_loss improved from 0.02620 to 0.02595, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 67s 7s/step - accuracy: 0.8566 - loss: 0.0219 - val_accuracy: 0.8131 - val_loss: 0.0259
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8438 - loss: 0.0235
# Epoch 49: val_loss did not improve from 0.02595
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.8425 - loss: 0.0236 - val_accuracy: 0.8182 - val_loss: 0.0286
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8582 - loss: 0.0228
# Epoch 50: val_loss improved from 0.02595 to 0.02546, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.8575 - loss: 0.0228 - val_accuracy: 0.8384 - val_loss: 0.0255
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8103 - loss: 0.0271
# Epoch 51: val_loss did not improve from 0.02546
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 69s 7s/step - accuracy: 0.8137 - loss: 0.0267 - val_accuracy: 0.8283 - val_loss: 0.0267
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8313 - loss: 0.0235
# Epoch 52: val_loss did not improve from 0.02546
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 7s/step - accuracy: 0.8320 - loss: 0.0235 - val_accuracy: 0.7980 - val_loss: 0.0300
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8587 - loss: 0.0208
# Epoch 53: val_loss did not improve from 0.02546
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 7s/step - accuracy: 0.8584 - loss: 0.0209 - val_accuracy: 0.7980 - val_loss: 0.0281
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8483 - loss: 0.0221
# Epoch 54: val_loss improved from 0.02546 to 0.02539, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 73s 7s/step - accuracy: 0.8491 - loss: 0.0220 - val_accuracy: 0.8333 - val_loss: 0.0254
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8594 - loss: 0.0204
# Epoch 55: val_loss improved from 0.02539 to 0.02523, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.8593 - loss: 0.0204 - val_accuracy: 0.8384 - val_loss: 0.0252
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8790 - loss: 0.0191
# Epoch 56: val_loss improved from 0.02523 to 0.02522, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.8775 - loss: 0.0192 - val_accuracy: 0.8384 - val_loss: 0.0252
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8678 - loss: 0.0191
# Epoch 57: val_loss improved from 0.02522 to 0.02338, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.8682 - loss: 0.0191 - val_accuracy: 0.8535 - val_loss: 0.0234
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8809 - loss: 0.0178
# Epoch 58: val_loss did not improve from 0.02338
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step - accuracy: 0.8802 - loss: 0.0179 - val_accuracy: 0.8182 - val_loss: 0.0255
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8523 - loss: 0.0219
# Epoch 59: val_loss did not improve from 0.02338
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step - accuracy: 0.8537 - loss: 0.0218 - val_accuracy: 0.7828 - val_loss: 0.0285
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8846 - loss: 0.0180
# Epoch 60: val_loss did not improve from 0.02338
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 67s 7s/step - accuracy: 0.8839 - loss: 0.0181 - val_accuracy: 0.8333 - val_loss: 0.0244
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8922 - loss: 0.0174
# Epoch 61: val_loss improved from 0.02338 to 0.02330, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step - accuracy: 0.8911 - loss: 0.0175 - val_accuracy: 0.8434 - val_loss: 0.0233
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8929 - loss: 0.0169
# Epoch 62: val_loss improved from 0.02330 to 0.02277, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 72s 7s/step - accuracy: 0.8927 - loss: 0.0169 - val_accuracy: 0.8434 - val_loss: 0.0228
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8594 - loss: 0.0204
# Epoch 63: val_loss did not improve from 0.02277
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 72s 7s/step - accuracy: 0.8610 - loss: 0.0203 - val_accuracy: 0.8283 - val_loss: 0.0245
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8966 - loss: 0.0150
# Epoch 64: val_loss did not improve from 0.02277
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.8958 - loss: 0.0151 - val_accuracy: 0.8030 - val_loss: 0.0250
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8872 - loss: 0.0177
# Epoch 65: val_loss did not improve from 0.02277
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8858 - loss: 0.0178 - val_accuracy: 0.8434 - val_loss: 0.0230
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8929 - loss: 0.0154
# Epoch 66: val_loss improved from 0.02277 to 0.02218, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.8926 - loss: 0.0155 - val_accuracy: 0.8434 - val_loss: 0.0222
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8885 - loss: 0.0174
# Epoch 67: val_loss did not improve from 0.02218
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.8890 - loss: 0.0174 - val_accuracy: 0.8384 - val_loss: 0.0251
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8838 - loss: 0.0177
# Epoch 68: val_loss did not improve from 0.02218
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8837 - loss: 0.0177 - val_accuracy: 0.8182 - val_loss: 0.0255
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8828 - loss: 0.0179
# Epoch 69: val_loss improved from 0.02218 to 0.02040, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8832 - loss: 0.0179 - val_accuracy: 0.8535 - val_loss: 0.0204
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8891 - loss: 0.0165
# Epoch 70: val_loss did not improve from 0.02040
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8886 - loss: 0.0165 - val_accuracy: 0.8232 - val_loss: 0.0237
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8833 - loss: 0.0167
# Epoch 71: val_loss improved from 0.02040 to 0.02017, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8835 - loss: 0.0167 - val_accuracy: 0.8737 - val_loss: 0.0202
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9151 - loss: 0.0136
# Epoch 72: val_loss did not improve from 0.02017
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9135 - loss: 0.0138 - val_accuracy: 0.8232 - val_loss: 0.0277
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8863 - loss: 0.0175
# Epoch 73: val_loss improved from 0.02017 to 0.01965, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8864 - loss: 0.0174 - val_accuracy: 0.8687 - val_loss: 0.0197
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9057 - loss: 0.0155
# Epoch 74: val_loss improved from 0.01965 to 0.01840, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9054 - loss: 0.0155 - val_accuracy: 0.8838 - val_loss: 0.0184
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9097 - loss: 0.0140
# Epoch 75: val_loss did not improve from 0.01840
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9095 - loss: 0.0140 - val_accuracy: 0.8131 - val_loss: 0.0282
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8650 - loss: 0.0202
# Epoch 76: val_loss did not improve from 0.01840
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8672 - loss: 0.0199 - val_accuracy: 0.8485 - val_loss: 0.0223
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9162 - loss: 0.0139
# Epoch 77: val_loss did not improve from 0.01840
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9161 - loss: 0.0139 - val_accuracy: 0.8535 - val_loss: 0.0203
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9206 - loss: 0.0126
# Epoch 78: val_loss improved from 0.01840 to 0.01814, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9202 - loss: 0.0126 - val_accuracy: 0.8788 - val_loss: 0.0181
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9270 - loss: 0.0124
# Epoch 79: val_loss did not improve from 0.01814
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9263 - loss: 0.0124 - val_accuracy: 0.8182 - val_loss: 0.0257
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9074 - loss: 0.0148
# Epoch 80: val_loss did not improve from 0.01814
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9074 - loss: 0.0147 - val_accuracy: 0.8434 - val_loss: 0.0210
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8842 - loss: 0.0173
# Epoch 81: val_loss did not improve from 0.01814
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.8861 - loss: 0.0170 - val_accuracy: 0.8737 - val_loss: 0.0193
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9283 - loss: 0.0112
# Epoch 82: val_loss did not improve from 0.01814
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9277 - loss: 0.0112 - val_accuracy: 0.8636 - val_loss: 0.0188
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9083 - loss: 0.0132
# Epoch 83: val_loss improved from 0.01814 to 0.01689, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9094 - loss: 0.0131 - val_accuracy: 0.8939 - val_loss: 0.0169
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9287 - loss: 0.0110
# Epoch 84: val_loss did not improve from 0.01689
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9281 - loss: 0.0110 - val_accuracy: 0.8939 - val_loss: 0.0170
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9315 - loss: 0.0113
# Epoch 85: val_loss did not improve from 0.01689
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9305 - loss: 0.0114 - val_accuracy: 0.8838 - val_loss: 0.0175
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9407 - loss: 0.0110
# Epoch 86: val_loss did not improve from 0.01689
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9404 - loss: 0.0110 - val_accuracy: 0.8737 - val_loss: 0.0186
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9069 - loss: 0.0127
# Epoch 87: val_loss did not improve from 0.01689
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 36s 4s/step - accuracy: 0.9084 - loss: 0.0126 - val_accuracy: 0.8586 - val_loss: 0.0200
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9314 - loss: 0.0104
# Epoch 88: val_loss did not improve from 0.01689
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9317 - loss: 0.0103 - val_accuracy: 0.8434 - val_loss: 0.0218
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9205 - loss: 0.0118
# Epoch 89: val_loss did not improve from 0.01689
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9204 - loss: 0.0118 - val_accuracy: 0.7879 - val_loss: 0.0307
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8787 - loss: 0.0158
# Epoch 90: val_loss did not improve from 0.01689
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.8803 - loss: 0.0157 - val_accuracy: 0.8838 - val_loss: 0.0175
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9137 - loss: 0.0130
# Epoch 91: val_loss improved from 0.01689 to 0.01617, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9148 - loss: 0.0129 - val_accuracy: 0.8939 - val_loss: 0.0162
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9356 - loss: 0.0104
# Epoch 92: val_loss improved from 0.01617 to 0.01612, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9357 - loss: 0.0104 - val_accuracy: 0.8939 - val_loss: 0.0161
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9413 - loss: 0.0102
# Epoch 93: val_loss improved from 0.01612 to 0.01601, saving model to top_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9408 - loss: 0.0102 - val_accuracy: 0.8889 - val_loss: 0.0160
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9355 - loss: 0.0117
# Epoch 94: val_loss did not improve from 0.01601
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9356 - loss: 0.0116 - val_accuracy: 0.8889 - val_loss: 0.0164
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9347 - loss: 0.0103
# Epoch 95: val_loss did not improve from 0.01601
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9347 - loss: 0.0103 - val_accuracy: 0.8990 - val_loss: 0.0161
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9459 - loss: 0.0092
# Epoch 96: val_loss did not improve from 0.01601
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9455 - loss: 0.0093 - val_accuracy: 0.8838 - val_loss: 0.0166
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9418 - loss: 0.0094
# Epoch 97: val_loss did not improve from 0.01601
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9413 - loss: 0.0095 - val_accuracy: 0.8081 - val_loss: 0.0277
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9112 - loss: 0.0134
# Epoch 98: val_loss did not improve from 0.01601
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9128 - loss: 0.0133 - val_accuracy: 0.8333 - val_loss: 0.0216
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9385 - loss: 0.0106
# Epoch 99: val_loss did not improve from 0.01601
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.9378 - loss: 0.0107 - val_accuracy: 0.8081 - val_loss: 0.0283
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9001 - loss: 0.0147
# Epoch 100: val_loss did not improve from 0.01601
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step - accuracy: 0.9020 - loss: 0.0145 - val_accuracy: 0.8889 - val_loss: 0.0167
# Restoring model weights from the end of the best epoch: 93.
# Test loss: 0.016009274870157242
# Test accuracy: 0.8888888955116272

# %% [markdown]
# ### Model Evaluation
#
# #### Evaluating the model by loading the best model saved and passing the test dataset

# %%
model = load_model('top_model.keras')
score = model.evaluate(testX, testY, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.016009274870157242
# Test accuracy: 0.8888888955116272

# %% [markdown]
# #### Now, testing the model on unseen data
#
# #### Created Test Fonts folder with newly generated font images using .ttf files. The script to generate the images is present in another ipyn file named 'Font image generation script'

# %%
img_path='Test Fonts'

def rev_conv_label(label):
    labels = [
        'AguafinaScript', 'AlexBrush', 'Allura', 'alsscrp', 'Canterbury',
        'GreatVibes', 'Holligate Signature', 'I Love Glitter', 'James Fajardo', 'OpenSans'
    ]
    return labels[label]


# Process each image in the directory
for image_file in os.listdir(img_path):
    try:
    
        # Construct full image path
        full_path = os.path.join(img_path, image_file)
    
        # Open, convert to RGB, and convert to array
        pil_im = PIL.Image.open(full_path).convert('RGB')
        pil_im = pil_im.resize((105, 105))
        org_img = img_to_array(pil_im)
        org_img = np.expand_dims(org_img, axis=0)  # Model expects a batch of images

        # Normalize the image
        org_img = org_img.astype('float') / 255.0

        # Predict the font
        y = model.predict(org_img)
        y = np.argmax(y, axis=1)  # Get the index of the max log-probability
        label = rev_conv_label(y[0])  # Convert numerical label to actual font name

        # Plot and annotate image with predicted label
        fig, ax = plt.subplots()
        ax.imshow(pil_im, cmap='gray')
        ax.axis('off')  # Hide axes
        ax.text(5, 5, label, color='blue', bbox=dict(facecolor='white', alpha=0.75, edgecolor='none', boxstyle='round,pad=0.5'))
        plt.show()
    except:
        None
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
